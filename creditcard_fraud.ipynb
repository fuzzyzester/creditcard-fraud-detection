# %% [markdown]
# ## Credit card fraud

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\riann\Downloads\creditcard.csv\creditcard.csv")
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %% [markdown]
# ## EDA

# %%
df.shape
df.info()
df.columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
# Time	Represents seconds since the first transaction. Ranges from 0 to 172792. Could be converted into hour/day.
# V1–V28	PCA-transformed features wc is already scaled and anonymized.
# Amount	Not scaled. Ranges from 0 to 25,691. Will need scaling.
# Class	0 or 1 — target variable. Most values are 0 (non-fraud).

# %% [markdown]
# ### understand the data

# %% [markdown]
# ### Check missing, duplicates or corrupted data

# %%
print("Missing values:\n", df.isnull().sum())
print("Duplicate rows:", df.duplicated().sum())
# Out:
# Missing values:
#  Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64
# Duplicate rows: 1081

# %% [markdown]
# ### Check class distribution

# %%
print("Class counts:")
print(df['Class'].value_counts())

print("\n Class distribution (%):")
print(df['Class'].value_counts(normalize=True) * 100)
# Out:
# Class counts:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64
#
#  Class distribution (%):
# Class
# 0    99.827251
# 1     0.172749
# Name: proportion, dtype: float64

# %%
# dataset is extremly imbalance

# %% [markdown]
# ### Analyze, visualize - check if this needs to normalize

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Distribution of transaction amounts
sns.histplot(df['Amount'], bins=50, kde=True)
plt.title("Transaction Amount Distribution")
plt.xlabel("Amount")
plt.ylabel("Frequency")
plt.show()

# Summary stats
print(df['Amount'].describe())
# Out:
# count    284807.000000
# mean         88.349619
# std         250.120109
# min           0.000000
# 25%           5.600000
# 50%          22.000000
# 75%          77.165000
# max       25691.160000
# Name: Amount, dtype: float64

# %% [markdown]
# #Highly skewed toward smaller values. Most transactions are under 100 SEK. A few go up to 25,000+ SEK — outliers
# #Stat	Value
# #Min	0.00
# #Mean	88.35
# #Median	22.00
# #Max	25,691.16
# #This shows a long right tail — common in financial data. It also confirms that this feature should be scaled before training

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(x='Class', y='Amount', data=df)
plt.title("Transaction Amount by Class")
plt.xlabel("Class (0 = Normal, 1 = Fraud)")
plt.ylabel("Amount")
plt.yscale("log") 
plt.show()

# %% [markdown]
# Fraudulent transactions tend to be smaller on average, but still have some high-value outliers.
# Amount alone isn't enough to detect fraud but is still useful when combined with other features.
# We'll scale it to match the PCA'd features (V1–V28) in the next step.

# %% [markdown]
# ### Correlational heatmap

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Compute correlation matrix
corr_matrix = df.corr()

# Plot the heatmap
plt.figure(figsize=(16, 12))
sns.heatmap(corr_matrix, cmap='coolwarm', center=0, linewidths=0.5)
plt.title("🔍 Correlation Heatmap")
plt.show()
# Out:
# C:\Users\riann\anomaly_detection_project\env\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128269 (\N{LEFT-POINTING MAGNIFYING GLASS}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# V14: strong negative correlation with Class.
# V12: strong negative.
# V10: strong negative.
# V17, V18, V4, V7 may have small positive/negative correlations.

# %% [markdown]
# Features with low or no correlation to Class:
# Time: very weak correlation → typically dropped.
# Amount: low correlation but still used after scaling.

# %% [markdown]
# -Drop irrelevant columns (like Time).
# -Scale the Amount column.
# -Rename the scaled Amount column.
# -Separate features and target (X and y).

# %% [markdown]
# ### Data preparation and modelling

# %%
from sklearn.preprocessing import StandardScaler

df.drop(['Time'], axis=1, inplace=True)

scaler = StandardScaler()
df['Scaled_Amount'] = scaler.fit_transform(df[['Amount']])

df.drop(['Amount'], axis=1, inplace=True)

columns = list(df.columns)
columns.remove('Class')
columns.append('Class')
df = df[columns]

print("Final dataset ready for modeling. Here's the shape:")
print(df.shape)
df.head()
# Out:
# Final dataset ready for modeling. Here's the shape:
# (284807, 30)
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10  ...       V21       V22       V23       V24  \
# 0  0.098698  0.363787  0.090794  ... -0.018307  0.277838 -0.110474  0.066928
# 1  0.085102 -0.255425 -0.166974  ... -0.225775 -0.638672  0.101288 -0.339846
# 2  0.247676 -1.514654  0.207643  ...  0.247998  0.771679  0.909412 -0.689281
# 3  0.377436 -1.387024 -0.054952  ... -0.108300  0.005274 -0.190321 -1.175575
# 4 -0.270533  0.817739  0.753074  ... -0.009431  0.798278 -0.137458  0.141267
#
# ...

# %% [markdown]
# All PCA features (V1 to V28)
# A scaled Amount column → Scaled_Amount
# The target column → Class
# dropped Time, which adds no predictive value

# %% [markdown]
# ### Train and evaluate models

# %%
#import tools
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
from sklearn.model_selection import train_test_split

X = df.drop('Class', axis=1)
y = df['Class']

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, stratify=y, random_state=42
)

print("X_train shape:", X_train.shape)
print("y_train shape:", y_train.shape)
# Out:
# X_train shape: (227845, 29)
# y_train shape: (227845,)

# %%
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

def evaluate_model(model, X_test, y_test, model_name="Model"):
    y_pred = model.predict(X_test)
    y_prob = model.predict_proba(X_test)[:, 1] if hasattr(model, "predict_proba") else y_pred

    print(f"\n🔍 {model_name} Evaluation")
    
    # Confusion Matrix
    cm = confusion_matrix(y_test, y_pred)
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
    plt.title(f'{model_name} - Confusion Matrix')
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.show()
    
    # Classification Report
    print("Classification Report:")
    print(classification_report(y_test, y_pred, digits=4))

    # ROC AUC
    roc_score = roc_auc_score(y_test, y_prob)
    print(f"ROC AUC Score: {roc_score:.4f}")
    
    # Metrics summary
    report = classification_report(y_test, y_pred, output_dict=True)
    return {
        "Model": model_name,
        "Precision (1)": report["1"]["precision"],
        "Recall (1)": report["1"]["recall"],
        "F1-score (1)": report["1"]["f1-score"],
        "ROC-AUC": roc_score
    }

# %%
models = {
    "Logistic Regression": log_model,
    "Random Forest": rf_model,
    "XGBoost": xgb_model
}

evaluation_results = []

for name, model in models.items():
    result = evaluate_model(model, X_test, y_test, model_name=name)
    evaluation_results.append(result)

# Create a DataFrame to compare
results_df = pd.DataFrame(evaluation_results)
results_df.set_index("Model", inplace=True)
results_df
# Out:
# 🔍 Logistic Regression Evaluation
# Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.9999    0.9735    0.9865     56864
#            1     0.0563    0.9184    0.1061        98
#
#     accuracy                         0.9734     56962
#    macro avg     0.5281    0.9459    0.5463     56962
# weighted avg     0.9982    0.9734    0.9850     56962
#
# ROC AUC Score: 0.9700
#
# 🔍 Random Forest Evaluation
# Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.9997    0.9999    0.9998     56864
#            1     0.9432    0.8469    0.8925        98
#
#     accuracy                         0.9996     56962
#    macro avg     0.9715    0.9234    0.9461     56962
# weighted avg     0.9996    0.9996    0.9996     56962
#
# ROC AUC Score: 0.9575
#
# 🔍 XGBoost Evaluation
# Classification Report:
#               precision    recall  f1-score   support
#
# ...

# %%
log_model.fit(X_train, y_train)
rf_model.fit(X_train, y_train)
xgb_model.fit(X_train, y_train)
# Out:
# C:\Users\riann\anomaly_detection_project\env\Lib\site-packages\xgboost\training.py:183: UserWarning: [09:54:30] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, feature_weights=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
# ...

# %%
evaluate_train_test(log_model, X_train, y_train, X_test, y_test, "Logistic Regression")
evaluate_train_test(rf_model, X_train, y_train, X_test, y_test, "Random Forest")
evaluate_train_test(xgb_model, X_train, y_train, X_test, y_test, "XGBoost")
# Out:
#  Logistic Regression - Performance Comparison
# Train F1-Score (1): 0.7500 | ROC-AUC: 0.9822
# Test  F1-Score (1): 0.7241 | ROC-AUC: 0.9560
#  No major overfitting.
#
#  Random Forest - Performance Comparison
# Train F1-Score (1): 1.0000 | ROC-AUC: 1.0000
# Test  F1-Score (1): 0.8925 | ROC-AUC: 0.9575
#   Possible overfitting detected.
#
#  XGBoost - Performance Comparison
# Train F1-Score (1): 0.9987 | ROC-AUC: 1.0000
# Test  F1-Score (1): 0.8342 | ROC-AUC: 0.9268
#   Possible overfitting detected.

# %%
import joblib
joblib.dump(log_model, "fraud_model_final.pkl")
# Out:
# ['fraud_model_final.pkl']

# %%
def evaluate_train_test(model, X_train, y_train, X_test, y_test, model_name="Model"):
    from sklearn.metrics import classification_report, roc_auc_score

    # TRAIN
    y_pred_train = model.predict(X_train)
    y_prob_train = model.predict_proba(X_train)[:, 1] if hasattr(model, "predict_proba") else y_pred_train
    report_train = classification_report(y_train, y_pred_train, output_dict=True)
    roc_auc_train = roc_auc_score(y_train, y_prob_train)

    # TEST
    y_pred_test = model.predict(X_test)
    y_prob_test = model.predict_proba(X_test)[:, 1] if hasattr(model, "predict_proba") else y_pred_test
    report_test = classification_report(y_test, y_pred_test, output_dict=True)
    roc_auc_test = roc_auc_score(y_test, y_prob_test)

    print(f"\n {model_name} - Performance Comparison")
    print(f"Train F1-Score (1): {report_train['1']['f1-score']:.4f} | ROC-AUC: {roc_auc_train:.4f}")
    print(f"Test  F1-Score (1): {report_test['1']['f1-score']:.4f} | ROC-AUC: {roc_auc_test:.4f}")

    if report_train['1']['f1-score'] - report_test['1']['f1-score'] > 0.1:
        print("  Possible overfitting detected.")
    elif report_test['1']['f1-score'] > report_train['1']['f1-score']:
        print(" Model is generalizing well.")
    else:
        print(" No major overfitting.")

# %% [markdown]
# ### looking for Best model

# %%
from sklearn.metrics import classification_report, roc_auc_score

model_results = {}


def evaluate_and_store(model, X_test, y_test, model_name="Model"):
    y_pred = model.predict(X_test)
    y_prob = model.predict_proba(X_test)[:, 1] if hasattr(model, "predict_proba") else y_pred

    report = classification_report(y_test, y_pred, output_dict=True)
    roc_auc = roc_auc_score(y_test, y_prob)

    model_results[model_name] = {
        "precision": report["1"]["precision"],
        "recall": report["1"]["recall"],
        "f1_score": report["1"]["f1-score"],
        "roc_auc": roc_auc
    }


evaluate_and_store(log_model, X_test, y_test, "Logistic Regression")
evaluate_and_store(rf_model, X_test, y_test, "Random Forest")
evaluate_and_store(xgb_model, X_test, y_test, "XGBoost")

# Convert to DataFrame for better view
import pandas as pd

results_df = pd.DataFrame(model_results).T
print("\n Model Comparison:")
display(results_df)

# Find best model by F1-Score (or ROC AUC)
best_by_f1 = results_df['f1_score'].idxmax()
best_by_auc = results_df['roc_auc'].idxmax()

print(f"\n Best model by F1-Score: {best_by_f1}")
print(f" Best model by ROC AUC: {best_by_auc}")
# Out:
#  Model Comparison:
#                      precision    recall  f1_score   roc_auc
# Logistic Regression   0.828947  0.642857  0.724138  0.955973
# Random Forest         0.943182  0.846939  0.892473  0.957517
# XGBoost               0.876404  0.795918  0.834225  0.926820
#  Best model by F1-Score: Random Forest
#  Best model by ROC AUC: Random Forest

# %% [markdown]
# It has the highest F1-score (best balance of precision & recall).
#
# Easier to interpret and faster to train.
#
# Excellent performance across all metrics.

# %% [markdown]
# ## Tune the best model

# %% [markdown]
# with randomizesearch since data is large and have good result

# %% [markdown]
# ### Set up tuning

# %%
from sklearn.ensemble import RandomForestClassifier

# Tuned Random Forest (to reduce overfitting)
rf_final = RandomForestClassifier(
    n_estimators=80,             
    max_depth=10,               
    min_samples_split=10,        
    min_samples_leaf=4,          
    max_features='sqrt',         
    bootstrap=True,              
    class_weight='balanced',    
    random_state=42
)

# Fit the tuned model
rf_final.fit(X_train, y_train)
# Out:
# RandomForestClassifier(class_weight='balanced', max_depth=10,
#                        min_samples_leaf=4, min_samples_split=10,
#                        n_estimators=80, random_state=42)

# %%
evaluate_train_test(rf_final, X_train, y_train, X_test, y_test, "Random Forest (Tuned)")
# Out:
#  Random Forest (Tuned) - Performance Comparison
# Train F1-Score (1): 0.9372 | ROC-AUC: 1.0000
# Test  F1-Score (1): 0.8182 | ROC-AUC: 0.9845
#   Possible overfitting detected.

# %% [markdown]
# 🔹 Still slightly overfitting — but not extreme.
#
# 🔹 F1-Score dropped ~12%, which is acceptable in fraud detection, especially when recall is good.
#
# ✅ ROC-AUC is excellent (0.98 on test).
#
# ✅ Balanced generalization and performance — good enough to deploy if you’re not in a high-risk environment.

# %%
import joblib


joblib.dump(rf_final, r"C:\Users\riann\fraud_api\random_forest_final_model.pkl")

print(" Model saved to C:\\Users\\riann\\fraud_api")
# Out:
#  Model saved to C:\Users\riann\fraud_api

# %% [markdown]
# ### check the best parameter

# %%
print("Best Random Forest Parameters:")
print(random_search_rf.best_params_)
# Out:
# Best Random Forest Parameters:
# {'n_estimators': 100, 'min_samples_split': 5, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'max_depth': None, 'bootstrap': False}

# %% [markdown]
# ### Train model with best parameters

# %%
from sklearn.ensemble import RandomForestClassifier

# Use your best parameters
rf_model = RandomForestClassifier(
    n_estimators=100,
    min_samples_split=5,
    min_samples_leaf=1,
    max_features='sqrt',
    max_depth=None,
    bootstrap=False,
    random_state=42  # ensures reproducibility
)

rf_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=False, min_samples_split=5, random_state=42)

# %% [markdown]
# ### Pedictions and probailities

# %%
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score, roc_curve
import matplotlib.pyplot as plt
import seaborn as sns

y_pred = rf_model.predict(X_test)
y_proba = rf_model.predict_proba(X_test)[:, 1]  # for ROC

# %%
# Confusion matrix
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
# classification report
print("Classification Report:\n")
print(classification_report(y_test, y_pred))
# Out:
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.94      0.85      0.89        98
#
#     accuracy                           1.00     56962
#    macro avg       0.97      0.92      0.95     56962
# weighted avg       1.00      1.00      1.00     56962

# %% [markdown]
# Class 0 (non-fraud / negative class): Perfect scores — model is very confident and accurate.
#
# Class 1 (fraud / positive class):
#
# Precision = 94%: Great! When it predicts fraud, it's usually correct.
#
# Recall = 85%: Good, but could improve — it misses ~15% of the actual fraud cases.
#
# F1-Score = 0.89: Balanced metric, still high.

# %%
#ROC - AUC
fpr, tpr, thresholds = roc_curve(y_test, y_proba)
roc_auc = roc_auc_score(y_test, y_proba)

plt.figure()
plt.plot(fpr, tpr, label=f'AUC = {roc_auc:.2f}')
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC-AUC Curve')
plt.legend(loc='lower right')
plt.show()

# %%
# feature importance
import pandas as pd
import numpy as np

feature_importance = pd.Series(rf_model.feature_importances_, index=X_train.columns)
top_features = feature_importance.sort_values(ascending=False).head(10)

plt.figure(figsize=(10, 5))
sns.barplot(x=top_features.values, y=top_features.index)
plt.title('Top 10 Feature Importances')
plt.xlabel('Importance Score')
plt.ylabel('Features')
plt.tight_layout()
plt.show()

# %%
#save csv for power BI
os.makedirs("exports", exist_ok=True)

results_df.to_csv("exports/fraud_predictions.csv", index=False)
print(" Predictions saved to:", os.path.abspath("exports/fraud_predictions.csv"))
# Out:
#  Predictions saved to: C:\Users\riann\anomaly_detection_project\exports\fraud_predictions.csv

# %% [markdown]
# ### Deploy model

# %%
#create the main.py
fastapi_code = '''
from fastapi import FastAPI
from pydantic import BaseModel
import joblib
import numpy as np

# Load the trained Random Forest model
model = joblib.load("random_forest_final_model.pkl")

FEATURES = [
    'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
    'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
    'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Scaled_Amount'
]

app = FastAPI()

class Transaction(BaseModel):
    V1: float; V2: float; V3: float; V4: float; V5: float; V6: float
    V7: float; V8: float; V9: float; V10: float; V11: float; V12: float
    V13: float; V14: float; V15: float; V16: float; V17: float; V18: float
    V19: float; V20: float; V21: float; V22: float; V23: float; V24: float
    V25: float; V26: float; V27: float; V28: float; Scaled_Amount: float

@app.post("/predict")
def predict(transaction: Transaction):
    input_data = np.array([[getattr(transaction, feature) for feature in FEATURES]])
    prediction = model.predict(input_data)[0]
    probability = model.predict_proba(input_data)[0][1]
    return {
        "prediction": int(prediction),
        "fraud_probability": round(float(probability), 4)
    }
'''


with open(r"C:\Users\riann\fraud_api\main.py", "w") as f:
    f.write(fastapi_code)

print("✅ main.py successfully saved to C:\\Users\\riann\\fraud_api")
# Out:
# ✅ main.py successfully saved to C:\Users\riann\fraud_api
